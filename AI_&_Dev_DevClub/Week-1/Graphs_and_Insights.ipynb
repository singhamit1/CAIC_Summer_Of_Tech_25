# %% [markdown]
# # **Given below are the results of 5 header datasets in various graphical presentation**:

# %% [markdown]
# ## **Distributions**

# %% [markdown]
# ![download.png](data:image/png;base64,...)![download (1).png](data:image/png;base64,...)![download (2).png](data:image/png;base64,...)![download (3).png](data:image/png;base64,...)

# %% [markdown]
# ## **Categorical Distributions**

# %% [markdown]
# ![download (7).png](data:image/png;base64,...)![download (4).png](data:image/png;base64,...)![download (6).png](data:image/png;base64,...)![download (5).png](data:image/png;base64,...)

# %% [markdown]
# ## **2-D Distributions**

# %% [markdown]
# ![download (8).png](data:image/png;base64,...)![download (10).png](data:image/png;base64,...)![download (9).png](data:image/png;base64,...)![download (11).png](data:image/png;base64,...)

# %% [markdown]
# ## **Time Series**

# %% [markdown]
# ![download (14).png](data:image/png;base64,...)![download (12).png](data:image/png;base64,...)![download (13).png](data:image/png;base64,...)![download (15).png](data:image/png;base64,...)

# %% [markdown]
# ## **Values**

# %% [markdown]
# ![download (16).png](data:image/png;base64,...)![download (17).png](data:image/png;base64,...)![download (18).png](data:image/png;base64,...)![download (19).png](data:image/png;base64,...)

# %% [markdown]
# ## **2-D Categorical Distributions**

# %% [markdown]
# ![download (21).png](data:image/png;base64,...)![download (22).png](data:image/png;base64,...)![download (20).png](data:image/png;base64,...)![download (23).png](data:image/png;base64,...)

# %% [markdown]
# ## **Faceted Distributions**

# %% [markdown]
# ![download (24).png](data:image/png;base64,...)![download (26).png](data:image/png;base64,...)![download (25).png](data:image/png;base64,...)![download (27).png](data:image/png;base64,...)

# %% [markdown]
# # **Insights**

# %% [markdown]
# # **1.   Time of Tweeting**
#           Peak like engagement occurs when tweets are posted in the evening hours (around 6–9 PM).
# # **2.   Type of Tweet**
#           Original tweets (not replies or retweets) receive the highest likes.
# # **3.   Content Elements**
#           Tweets with Hashtags has Slightly better engagement.
